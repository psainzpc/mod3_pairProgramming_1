# %%
# importamos las librerías que necesitamos

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np


# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
# cargamos el dataframe creado en la lección anterior
df = pd.read_csv("archivos-ejercicios/world_data_full.csv", index_col = 0)
df.head()
# Out:
#        country density abbreviation  agricultural_land  land_area  \
# 0  Afghanistan      60           AF               58.1    652,230
# 1      Albania     105           AL               43.1     28,748
# 2      Algeria      18           DZ               17.4  2,381,741
# 3      Andorra     164           AD               40.0        468
# 4       Angola      26           AO               47.5  1,246,700
#
#   armed_forces_size  birth_rate  calling_code capital/major_city  \
# 0           323,000       32.49          93.0              Kabul
# 1             9,000       11.78         355.0             Tirana
# 2           317,000       24.28         213.0            Algiers
# 3               NaN        7.20         376.0   Andorra la Vella
# 4           117,000       40.73         244.0             Luanda
#
#   co2-emissions     cpi  cpi_change currency-code  fertility_rate  \
# 0         8,672   149.9         2.3           AFN            4.47
# ...

# %% [markdown]
# # Ejercicios apply
# 1.Las columnas land_area, armed_forces_size, co2-emissions, gdp, population, urban_population, latitude, longitude, density, cpi son de tipo object pero en realidad deberían ser numéricas. Crea una función que nos permita cambiar el tipo de dato de estas columnas al que le corresponde

# %%
# Nan es un float
def replace(dato):
    try: 
        if dato.find(","):
            print(f"Entra en el if y el dato es {dato}")
            return float(round(dato.replace(",", ".")),2)
        else: 
            print(f"Entra en el else y el dato es {dato}")
            return float(dato)
    except: 
        print(f"Entra en el except y el dato es {dato}")
        np.nan

# %%
def convertir_a_numerico(dato): 
    try:
        dato = dato.astype(float, errors='ignore') 
        return dato # Aplicar la función al DataFrame df = convertir_a_numerico(df, columnas_numericas)
    except:
        return np.nan

# %%
# def convertir_a_numerico(columnas): 
#     columnas = columnas.apply(pd.to_numeric, errors='coerce') 
#     return df # Aplicar la función al DataFrame df = convertir_a_numerico(df, columnas_numericas) print(df) print(df.dtypes)  # Para verificar los tipos de datos

# %%
list_col = ["land_area", "armed_forces_size", "co2-emissions", "gdp", "population", "urban_population", "latitude", "longitude", "density", "cpi"]

for col in list_col:
    df[col] = df[col].apply(convertir_a_numerico)

# %%
df.head()
# Out:
#        country  density abbreviation  agricultural_land  land_area  \
# 0  Afghanistan      NaN           AF               58.1        NaN
# 1      Albania      NaN           AL               43.1        NaN
# 2      Algeria      NaN           DZ               17.4        NaN
# 3      Andorra      NaN           AD               40.0        NaN
# 4       Angola      NaN           AO               47.5        NaN
#
#    armed_forces_size  birth_rate  calling_code capital/major_city  \
# 0                NaN       32.49          93.0              Kabul
# 1                NaN       11.78         355.0             Tirana
# 2                NaN       24.28         213.0            Algiers
# 3                NaN        7.20         376.0   Andorra la Vella
# 4                NaN       40.73         244.0             Luanda
#
#    co2-emissions  cpi  cpi_change currency-code  fertility_rate  \
# 0            NaN  NaN         2.3           AFN            4.47
# ...
